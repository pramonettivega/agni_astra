# %%
# !pip install mljar-supervised
# Out:
# Requirement already satisfied: mljar-supervised in /usr/local/lib/python3.11/dist-packages (1.1.17)
# Requirement already satisfied: numpy<2,>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.26.4)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (2.2.2)
# Requirement already satisfied: scipy>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.14.1)
# Requirement already satisfied: scikit-learn>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.6.1)
# Requirement already satisfied: xgboost>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (2.1.4)
# Requirement already satisfied: lightgbm>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (4.5.0)
# Requirement already satisfied: catboost>=0.24.4 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.2.7)
# Requirement already satisfied: joblib>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.4.2)
# Requirement already satisfied: tabulate>=0.8.7 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (0.9.0)
# Requirement already satisfied: matplotlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (3.10.0)
# Requirement already satisfied: dtreeviz>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (2.2.2)
# Requirement already satisfied: shap>=0.42.1 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (0.47.1)
# Requirement already satisfied: seaborn>=0.11.1 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (0.13.2)
# Requirement already satisfied: wordcloud>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (1.9.4)
# Requirement already satisfied: category-encoders>=2.2.2 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (2.8.1)
# Requirement already satisfied: optuna-integration>=3.6.0 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (4.2.1)
# Requirement already satisfied: mljar-scikit-plot>=0.3.11 in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (0.3.12)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (3.7)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (4.13.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from mljar-supervised) (7.34.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost>=0.24.4->mljar-supervised) (0.20.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost>=0.24.4->mljar-supervised) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost>=0.24.4->mljar-supervised) (1.17.0)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.2.2->mljar-supervised) (1.0.1)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from category-encoders>=2.2.2->mljar-supervised) (0.14.4)
# Requirement already satisfied: colour in /usr/local/lib/python3.11/dist-packages (from dtreeviz>=2.2.2->mljar-supervised) (0.1.5)
# Requirement already satisfied: pytest in /usr/local/lib/python3.11/dist-packages (from dtreeviz>=2.2.2->mljar-supervised) (8.3.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.2.2->mljar-supervised) (2.8.2)
# Requirement already satisfied: optuna in /usr/local/lib/python3.11/dist-packages (from optuna-integration>=3.6.0->mljar-supervised) (4.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->mljar-supervised) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->mljar-supervised) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.5.0->mljar-supervised) (3.6.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap>=0.42.1->mljar-supervised) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap>=0.42.1->mljar-supervised) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap>=0.42.1->mljar-supervised) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap>=0.42.1->mljar-supervised) (3.1.1)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost>=2.0.0->mljar-supervised) (2.21.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->mljar-supervised) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->mljar-supervised) (0.8.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap>=0.42.1->mljar-supervised) (0.43.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->mljar-supervised) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->mljar-supervised) (0.2.13)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (1.15.2)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (6.9.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (2.0.40)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from optuna->optuna-integration>=3.6.0->mljar-supervised) (6.0.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost>=0.24.4->mljar-supervised) (9.1.2)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest->dtreeviz>=2.2.2->mljar-supervised) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest->dtreeviz>=2.2.2->mljar-supervised) (1.5.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic>=1.5.0->optuna->optuna-integration>=3.6.0->mljar-supervised) (1.1.3)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy>=1.4.2->optuna->optuna-integration>=3.6.0->mljar-supervised) (3.1.1)

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from supervised.automl import AutoML

# Load your dataset
df = pd.read_csv("X_y.csv")
X = df.drop(columns="GENUS")
y = df["GENUS"]

# Encode target
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=42)

# Initialize AutoML
automl = AutoML(
    mode="Compete",
    total_time_limit=180,   # total 10 minutes
    eval_metric="f1",
    algorithms=["LightGBM", "Xgboost"],
    random_state=42
)

# Train
automl.fit(X_train, y_train)

# Evaluate
print("\nEvaluation on test set:")
print(automl.report())
# Out:
# AutoML directory: AutoML_3
# The task is multiclass_classification with evaluation metric f1
# AutoML will use algorithms: ['LightGBM', 'Xgboost']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'mix_encoding', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree f1 0.640052 trained in 3.39 seconds
# Disable stacking for split validation
# Skip simple_algorithms because no parameters were generated.
# * Step default_algorithms will try to check up to 2 models
# There was an error during 2_Default_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 3_Default_Xgboost f1 0.819704 trained in 7.87 seconds
# * Step not_so_random will try to check up to 18 models
# There was an error during 12_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 3_Xgboost f1 0.822923 trained in 10.61 seconds
# There was an error during 13_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 4_Xgboost f1 0.807469 trained in 8.68 seconds
# There was an error during 14_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 5_Xgboost f1 0.812621 trained in 9.21 seconds
# There was an error during 15_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 6_Xgboost f1 0.819704 trained in 21.11 seconds
# There was an error during 16_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 7_Xgboost f1 0.788152 trained in 18.95 seconds
# There was an error during 17_LightGBM training.
# Please check AutoML_3/errors.md for details.
# 8_Xgboost f1 0.826787 trained in 13.93 seconds
# * Step mix_encoding will try to check up to 1 model
# 8_Xgboost_categorical_mix f1 0.828075 trained in 13.24 seconds
# Skip golden_features because of the time limit.
# * Step kmeans_features will try to check up to 3 models
# 8_Xgboost_categorical_mix_KMeansFeatures f1 0.819704 trained in 12.14 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 29.0 seconds
# Please increase total_time_limit to at least (348 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 7 models
# 9_Xgboost f1 0.820348 trained in 14.66 seconds
# 10_Xgboost f1 0.831938 trained in 13.49 seconds
# * Step hill_climbing_2 will try to check up to 7 models
# 11_Xgboost f1 0.823567 trained in 11.06 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble f1 0.831938 trained in 0.86 seconds
# AutoML fit time: 190.37 seconds
# AutoML best model: 10_Xgboost
#
# Evaluation on test set:
# <IPython.core.display.HTML object>

# %%
# This will print the leaderboard of trained models
leaderboard = automl.report()
print(leaderboard)
# Out:
# <IPython.core.display.HTML object>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split


# === LOAD YOUR TRAINING DATA ===
df = pd.read_csv("X_y.csv")
X = df.drop(columns="GENUS")
y = df["GENUS"]

# === LABEL ENCODE THE TARGET ===
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# === FEATURE ENGINEERING ===
X['HT_log'] = np.log1p(X['HT'])
X['DIA_log'] = np.log1p(X['DIA'])
X['HT_DIA_ratio'] = X['HT'] / (X['DIA'] + 1)
X['HT_minus_DIA'] = X['HT'] - X['DIA']
X['HT_times_DIA'] = X['HT'] * X['DIA']
X['LAT_LON_sum'] = X['LAT'] + X['LON']
X['LAT_LON_diff'] = X['LAT'] - X['LON']
X['ecosubcode_richness'] = X[[c for c in X.columns if 'ECOSUBCD_' in c]].sum(axis=1)
X['pft_type_count'] = X[[c for c in X.columns if 'PFT_' in c]].sum(axis=1)
X = X.drop(columns=["HT", "DIA"])

# === STANDARDIZE NUMERIC COLUMNS ===
numeric_cols = ['LAT', 'LON', 'HT_log', 'DIA_log', 'HT_DIA_ratio', 'HT_minus_DIA',
                'HT_times_DIA', 'LAT_LON_sum', 'LAT_LON_diff',
                'ecosubcode_richness', 'pft_type_count']
scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

# === TRAIN/TEST SPLIT ===
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, stratify=y_encoded, random_state=42)

# === RUN MLJAR AutoML ===
automl = AutoML(
    mode="Compete",
    total_time_limit=600,  # 10 minutes
    eval_metric="f1",
    algorithms=['Baseline', 'CatBoost', 'Decision Tree', 'Extra Trees', 'Nearest Neighbors', 'LightGBM', 'Linear', 'Neural Network', 'Random Forest', 'Xgboost'],
    random_state=42
)
automl.fit(X_train, y_train)

# === EVALUATE ===
print("Evaluation on test set:")
print(automl.report())

# === PREDICT ON NEW DATA ===
X_new = pd.read_csv("combined_df.csv")

# Feature engineering on test set
X_new['HT_log'] = X_new['HT']
X_new['DIA_log'] = X_new['DIA']
X_new['HT_DIA_ratio'] = X_new['HT'] / (X_new['DIA'] + 1)
X_new['HT_minus_DIA'] = X_new['HT'] - X_new['DIA']
X_new['HT_times_DIA'] = X_new['HT'] * X_new['DIA']
X_new['LAT_LON_sum'] = X_new['LAT'] + X_new['LON']
X_new['LAT_LON_diff'] = X_new['LAT'] - X_new['LON']
X_new['ecosubcode_richness'] = X_new[[c for c in X_new.columns if 'ECOSUBCD_' in c]].sum(axis=1)
X_new['pft_type_count'] = X_new[[c for c in X_new.columns if 'PFT_' in c]].sum(axis=1)
X_new = X_new.drop(columns=["HT", "DIA"])
X_new[numeric_cols] = scaler.transform(X_new[numeric_cols])
X_new = X_new[X_train.columns]  # align column order

# Make predictions
preds = automl.predict(X_new)
pred_labels = label_encoder.inverse_transform(preds)

# Show prediction distribution
dist = pd.Series(pred_labels).value_counts(normalize=True) * 100
print("\nPredicted GENUS Distribution:\n")
print(dist.sort_values(ascending=False))
# Out:
# Linear algorithm was disabled.
# AutoML directory: AutoML_5
# The task is multiclass_classification with evaluation metric f1
# AutoML will use algorithms: ['Baseline', 'CatBoost', 'Decision Tree', 'Extra Trees', 'Nearest Neighbors', 'LightGBM', 'Neural Network', 'Random Forest', 'Xgboost']
# AutoML will stack models
# AutoML will ensemble available models
# AutoML steps: ['adjust_validation', 'simple_algorithms', 'default_algorithms', 'not_so_random', 'mix_encoding', 'golden_features', 'kmeans_features', 'insert_random_feature', 'features_selection', 'hill_climbing_1', 'hill_climbing_2', 'boost_on_errors', 'ensemble', 'stack', 'ensemble_stacked']
# * Step adjust_validation will try to check up to 1 model
# 1_DecisionTree f1 0.650998 trained in 2.67 seconds
# Disable stacking for split validation
# * Step simple_algorithms will try to check up to 3 models
# 2_Baseline f1 0.276883 trained in 0.83 seconds
# 3_DecisionTree f1 0.51642 trained in 0.82 seconds
# 4_DecisionTree f1 0.522859 trained in 1.13 seconds
# * Step default_algorithms will try to check up to 7 models
# There was an error during 5_Default_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 6_Default_Xgboost f1 0.83387 trained in 19.42 seconds
# 7_Default_CatBoost f1 0.822923 trained in 12.95 seconds
# 8_Default_NeuralNetwork f1 0.701867 trained in 11.81 seconds
# 9_Default_RandomForest f1 0.666452 trained in 4.82 seconds
# 10_Default_ExtraTrees f1 0.658725 trained in 2.76 seconds
# 11_Default_NearestNeighbors f1 0.627173 trained in 1.68 seconds
# * Step not_so_random will try to check up to 61 models
# There was an error during 20_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 11_Xgboost f1 0.831938 trained in 13.96 seconds
# 29_CatBoost f1 0.806825 trained in 9.84 seconds
# 38_RandomForest f1 0.72698 trained in 14.53 seconds
# 47_ExtraTrees f1 0.710238 trained in 3.13 seconds
# 56_NeuralNetwork f1 0.618158 trained in 6.9 seconds
# 65_NearestNeighbors f1 0.645847 trained in 1.5 seconds
# There was an error during 21_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 12_Xgboost f1 0.819704 trained in 8.9 seconds
# 30_CatBoost f1 0.81584 trained in 10.94 seconds
# 39_RandomForest f1 0.629749 trained in 6.41 seconds
# 48_ExtraTrees f1 0.649066 trained in 2.61 seconds
# 57_NeuralNetwork f1 0.692209 trained in 8.08 seconds
# 66_NearestNeighbors f1 0.630393 trained in 1.64 seconds
# There was an error during 22_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 13_Xgboost f1 0.826143 trained in 11.66 seconds
# 31_CatBoost f1 0.810689 trained in 12.44 seconds
# 40_RandomForest f1 0.638764 trained in 5.52 seconds
# 49_ExtraTrees f1 0.654218 trained in 3.27 seconds
# 58_NeuralNetwork f1 0.691565 trained in 8.24 seconds
# 67_NearestNeighbors f1 0.630393 trained in 1.85 seconds
# There was an error during 23_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 14_Xgboost f1 0.820992 trained in 9.54 seconds
# 32_CatBoost f1 0.801674 trained in 9.3 seconds
# 41_RandomForest f1 0.668384 trained in 5.9 seconds
# 50_ExtraTrees f1 0.650998 trained in 3.27 seconds
# 59_NeuralNetwork f1 0.728912 trained in 12.94 seconds
# 68_NearestNeighbors f1 0.630393 trained in 2.7 seconds
# There was an error during 24_LightGBM training.
# Please check AutoML_5/errors.md for details.
# 15_Xgboost f1 0.793947 trained in 10.88 seconds
# 33_CatBoost f1 0.817772 trained in 14.51 seconds
# 42_RandomForest f1 0.644559 trained in 4.12 seconds
# 51_ExtraTrees f1 0.637476 trained in 4.23 seconds
# 60_NeuralNetwork f1 0.683194 trained in 8.94 seconds
# 69_NearestNeighbors f1 0.645847 trained in 2.2 seconds
# * Step mix_encoding will try to check up to 1 model
# 6_Default_Xgboost_categorical_mix f1 0.83387 trained in 21.1 seconds
# * Step golden_features will try to check up to 3 models
# None 10
# Add Golden Feature: PFT_Evergreen conifer_ratio_LAT_LON_sum
# Add Golden Feature: LAT_ratio_PFT_Evergreen conifer
# Add Golden Feature: PFT_Evergreen conifer_multiply_LAT
# Add Golden Feature: PFT_Evergreen conifer_ratio_LAT
# Add Golden Feature: LAT_LON_sum_ratio_PFT_Evergreen conifer
# Add Golden Feature: LAT_LON_sum_multiply_PFT_Evergreen conifer
# Add Golden Feature: PFT_Evergreen conifer_ratio_LAT_LON_diff
# Add Golden Feature: LAT_LON_diff_multiply_PFT_Evergreen conifer
# Add Golden Feature: LAT_LON_diff_ratio_PFT_Evergreen conifer
# Add Golden Feature: LON_ratio_PFT_Evergreen conifer
# Created 10 Golden Features in 13.66 seconds.
# 6_Default_Xgboost_categorical_mix_GoldenFeatures f1 0.832582 trained in 28.47 seconds
# 6_Default_Xgboost_GoldenFeatures f1 0.832582 trained in 14.76 seconds
# * Step kmeans_features will try to check up to 3 models
# 6_Default_Xgboost_categorical_mix_KMeansFeatures f1 0.831938 trained in 31.46 seconds
# Not enough time to perform features selection. Skip
# Time needed for features selection ~ 93.0 seconds
# Please increase total_time_limit to at least (993 seconds) to have features selection
# Skip insert_random_feature because no parameters were generated.
# Skip features_selection because no parameters were generated.
# * Step hill_climbing_1 will try to check up to 32 models
# 70_Xgboost f1 0.829363 trained in 15.53 seconds
# 71_Xgboost f1 0.838377 trained in 15.97 seconds
# 72_Xgboost f1 0.829363 trained in 15.59 seconds
# 73_Xgboost f1 0.838377 trained in 16.65 seconds
# 74_Xgboost_GoldenFeatures f1 0.835802 trained in 23.58 seconds
# * Step hill_climbing_2 will try to check up to 29 models
# 75_Xgboost f1 0.829363 trained in 13.31 seconds
# 76_Xgboost f1 0.829363 trained in 13.67 seconds
# 77_Xgboost_GoldenFeatures f1 0.833226 trained in 19.0 seconds
# * Step ensemble will try to check up to 1 model
# Ensemble f1 0.840309 trained in 9.61 seconds
# AutoML fit time: 647.12 seconds
# AutoML best model: Ensemble
# Evaluation on test set:
# <IPython.core.display.HTML object>
#
# Predicted GENUS Distribution:
#
# Pinus      68.895801
# Quercus    21.772939
# Abies       9.331260
# Name: proportion, dtype: float64
